# %%
"""
number_of_ensembles = list(range(1,16))
deep_ensemble_nll = [ 0.0925, 0.0651, 0.0571, 0.0546, 0.0544, 0.0539, 0.0524, 0.0516, 0.0510, 0.0498, 0.0488, 0.0481, 0.0484, 0.0477, 0.0475]

mc_dropout_nll = [ 0.1322, 0.1183, 0.1071, 0.1033, 0.0970, 0.0957, 0.0958, 0.0944, 0.0912, 0.0920, 0.0938, 0.0894, 0.0877, 0.0916, 0.0901]

classification_error_deep_ensemble = [ 2.36, 1.81, 1.75, 1.66, 1.61, 1.52, 1.46, 1.51, 1.44, 1.42, 1.43, 1.38, 1.37, 1.37, 1.40]

classification_error_mc_dropout = [ 2.98, 2.78, 2.58, 2.63, 2.44, 2.45, 2.49, 2.44, 2.40, 2.44, 2.44, 2.42, 2.45, 2.43, 2.50]

brier_score_deep_ensemble = [0.00376, 0.00291, 0.00260, 0.00245, 0.00245, 0.00241, 0.00236, 0.00230, 0.00227, 0.00223, 0.00221, 0.00218, 0.00217, 0.00216, 0.00215]

brier_score_mc_dropout = [0.00480, 0.00444, 0.00416, 0.00413, 0.00390, 0.00389, 0.00394, 0.00389, 0.00384, 0.00385, 0.00386, 0.00377, 0.00377, 0.00384, 0.00377]
"""

# %%
"""
nll_adversarial = [ 0.0751, 0.0599, 0.0555, 0.0523, 0.0504, 0.0483, 0.0470, 0.0469, 0.0462, 0.0451, 0.0445, 0.0440, 0.0440, 0.0440, 0.0441]

classification_error_adversarial = [ 2.16, 1.64, 1.54, 1.36, 1.36, 1.31, 1.30, 1.27, 1.32, 1.32, 1.25, 1.21, 1.21, 1.19, 1.20]

brier_score_adversarial = [0.00333, 0.00270, 0.00251, 0.00234, 0.00226, 0.00217, 0.00212, 0.00209, 0.00206, 0.00201, 0.00199, 0.00196, 0.00196, 0.00195, 0.00195]

nll_random = [0.0998, 0.0645, 0.0603, 0.0577, 0.0554, 0.0545, 0.0533, 0.0528, 0.0509, 0.0507, 0.0503, 0.0501, 0.0501, 0.0495, 0.0496]

classification_error_random = [2.32, 1.71, 1.58, 1.51, 1.49, 1.45, 1.45, 1.40, 1.37, 1.36, 1.35, 1.37, 1.36, 1.33, 1.31]

brier_score_random = [0.00374, 0.00283, 0.00265, 0.00258, 0.00248, 0.00249, 0.00241, 0.00236, 0.00230, 0.00228, 0.00226, 0.00225, 0.00225, 0.00223, 0.00223]
"""

# %%
"""
#40 EPOCHS
number_of_ensembles = list(range(1,16))
deep_ensemble_nll = [0.1323, 0.0789, 0.0659, 0.0591, 0.0551, 0.0503, 0.0444, 0.0428, 0.0429, 0.0424, 0.0413, 0.0410, 0.0405, 0.0407, 0.0398]
classification_error_deep_ensemble = [1.98, 1.59, 1.46, 1.48, 1.38, 1.33, 1.28, 1.22, 1.21, 1.23, 1.22, 1.22, 1.19, 1.18, 1.19]
brier_score_deep_ensemble = [0.00348, 0.00266, 0.00237, 0.00223, 0.00211, 0.00204, 0.00198, 0.00193, 0.00191, 0.00191, 0.00189, 0.00188, 0.00187, 0.00187, 0.00185]


mc_dropout_nll = [0.1602, 0.1327, 0.1150, 0.1117, 0.1046, 0.1111, 0.1008, 0.0995, 0.0958, 0.1000, 0.0967, 0.0960, 0.0934, 0.0936, 0.0918]
classification_error_mc_dropout = [2.70, 2.13, 2.13, 2.07, 1.96, 2.01, 2.01, 1.98, 2.00, 1.92, 1.94, 1.92, 1.96, 1.89, 1.90]
brier_score_mc_dropout = [0.00444, 0.00381, 0.00352, 0.00342, 0.00327, 0.00331, 0.00325, 0.00322, 0.00320, 0.00320, 0.00320, 0.00314, 0.00314, 0.00319, 0.00311]


nll_adversarial = [0.0669, 0.0466, 0.0375, 0.0376, 0.0371, 0.0361, 0.0348, 0.0346, 0.0332, 0.0323, 0.0321, 0.0316, 0.0318, 0.0317, 0.0311]
classification_error_adversarial = [1.59, 1.16, 1.11, 1.00, 1.04, 0.98, 1.00, 1.00, 0.98, 1.00, 0.97, 1.01, 1.01, 0.97, 0.92]
brier_score_adversarial = [0.00247, 0.00194, 0.00169, 0.00165, 0.00162, 0.00158, 0.00155, 0.00155, 0.00152, 0.00150, 0.00149, 0.00149, 0.00150, 0.00149, 0.00148]


nll_random = [0.1253, 0.0695, 0.0541, 0.0503, 0.0471, 0.0462, 0.0455, 0.0451, 0.0449, 0.0442, 0.0430, 0.0425, 0.0415, 0.0396, 0.0399]
classification_error_random = [2.02, 1.50, 1.30, 1.24, 1.16, 1.21, 1.17, 1.22, 1.24, 1.16, 1.14, 1.12, 1.11, 1.17, 1.15]
brier_score_random = [0.00356, 0.00241, 0.00212, 0.00195, 0.00190, 0.00188, 0.00187, 0.00184, 0.00183, 0.00181, 0.00179, 0.00179, 0.00177, 0.00175, 0.00176]
"""

# %%
#20 EPOCHS
number_of_ensembles = list(range(1,16))
deep_ensemble_nll = [0.0977, 0.0600, 0.0493, 0.0448, 0.0442, 0.0432, 0.0419, 0.0419, 0.0419, 0.0419, 0.0421, 0.0418, 0.0420, 0.0419, 0.0416]
classification_error_deep_ensemble = [2.02, 1.45, 1.38, 1.34, 1.42, 1.31, 1.35, 1.35, 1.33, 1.30, 1.33, 1.29, 1.27, 1.25, 1.20]
brier_score_deep_ensemble = [0.00318, 0.00243, 0.00218, 0.00208, 0.00207,  0.00203, 0.00200, 0.00199, 0.00197, 0.00198,  0.00198, 0.00196, 0.00194, 0.00194, 0.00193]

mc_dropout_nll = [0.1246, 0.1032, 0.1006, 0.0949, 0.0933,  0.0900, 0.0881, 0.0849, 0.0853, 0.0848, 0.0865, 0.0856, 0.0832, 0.0842, 0.0812]
classification_error_mc_dropout = [2.83, 2.30, 2.28, 2.19, 2.15, 2.24, 2.14, 2.20, 2.11, 2.14, 2.16, 2.06, 2.13, 2.12, 2.14]
brier_score_mc_dropout = [0.00450, 0.00378, 0.00368, 0.00360, 0.00352, 0.00344, 0.00338, 0.00341, 0.00336, 0.00331, 0.00332, 0.00326, 0.00328, 0.00330, 0.00329]

#nll_adversarial = [0.0660, 0.0489, 0.0421, 0.0383, 0.0375, 0.0367, 0.0364, 0.0360, 0.0355, 0.0358, 0.0354, 0.0349, 0.0349, 0.0348, 0.0345]
#classification_error_adversarial = [1.83, 1.39, 1.26, 1.06, 1.13, 1.06, 1.04, 1.05, 1.08, 1.01, 1.02, 0.990, 1.02, 0.960, 0.940]
#brier_score_adversarial = [0.00285, 0.00227, 0.00198, 0.00180, 0.00176, 0.00172, 0.00171, 0.00169, 0.00167, 0.00167, 0.00164, 0.00161, 0.00161, 0.00162, 0.00161]

nll_adversarial = [0.0743, 0.0518, 0.0463, 0.0431, 0.0401, 0.0388, 0.0380, 0.0365, 0.0356, 0.0352, 0.0349, 0.0343, 0.0340, 0.0341, 0.0340]
classification_error_adversarial = [1.760, 1.340, 1.410, 1.210, 1.150, 1.150, 1.120, 1.070, 1.090, 1.080, 1.060, 1.110, 1.090, 1.070, 1.070]
brier_score_adversarial = [0.00281, 0.00226, 0.00210, 0.00194, 0.00185, 0.00179, 0.00176, 0.00174, 0.00171, 0.00168, 0.00166, 0.00166, 0.00165, 0.00165, 0.00164]

#nll_random = [0.1115, 0.0635, 0.0520, 0.0471, 0.0451, 0.0460, 0.0450, 0.0436, 0.0431, 0.0430, 0.0420, 0.0419, 0.0418, 0.0419, 0.0418]
#classification_error_random = [2.43, 1.52, 1.51, 1.36, 1.33, 1.29, 1.32, 1.26, 1.27, 1.31, 1.28, 1.24, 1.22, 1.21, 1.22]
#brier_score_random = [0.00390, 0.00256, 0.00225, 0.00212, 0.00206, 0.00210, 0.00207, 0.00201, 0.00199, 0.00198, 0.00196, 0.00195, 0.00194, 0.00194, 0.00194]

nll_random = [0.1058, 0.0633, 0.0569, 0.0503, 0.0472, 0.0457, 0.0468, 0.0452, 0.0444, 0.0442, 0.0437, 0.0437, 0.0432, 0.0428, 0.0426]
classification_error_random = [2.330, 1.520, 1.460, 1.300, 1.330, 1.330, 1.320, 1.260, 1.240, 1.240, 1.250, 1.190, 1.180, 1.190, 1.170]
brier_score_random = [0.00369, 0.00268, 0.00245, 0.00225, 0.00214, 0.00210, 0.00211, 0.00206, 0.00202, 0.00200, 0.00198, 0.00198, 0.00197, 0.00195, 0.00195]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

plt.plot(number_of_ensembles, deep_ensemble_nll, label="Ensemble", color="red")
plt.plot(number_of_ensembles, mc_dropout_nll, label="MC Dropout", color="green")
plt.plot(number_of_ensembles, nll_random, label="Ensemble + R", color="grey")
plt.plot(number_of_ensembles, nll_adversarial, label="Ensemble + AT", color="blue")

plt.xlabel("Number of Nets", fontsize=18)
plt.ylabel("NLL", fontsize=18)
plt.title("NLL of Deep Ensembles vs MC Dropout", fontsize=20)

plt.legend(fontsize=18, markerscale=1.5)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.savefig("plots/nll_deep_ensembles_vs_mc_dropout")
plt.clf()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

plt.plot(number_of_ensembles, classification_error_deep_ensemble,
         label="Ensemble", color="red")

plt.plot(number_of_ensembles, classification_error_mc_dropout,
         label="MC Dropout", color="green")

plt.plot(number_of_ensembles, classification_error_random,
         label="Ensemble + R", color="grey")

plt.plot(number_of_ensembles, classification_error_adversarial,
         label="Ensemble + AT", color="blue")

plt.xlabel("Number of Nets", fontsize=18)
plt.ylabel("Classification Error (%)", fontsize=18)
plt.title("Classification Error of Deep Ensembles vs MC Dropout", fontsize=20)

plt.legend(fontsize=18, markerscale=1.5)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

plt.savefig("plots/classification_error_deep_ensembles_vs_mc_dropout")
plt.clf()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

plt.plot(number_of_ensembles, brier_score_deep_ensemble,
         label="Ensemble", color="red")

plt.plot(number_of_ensembles, brier_score_mc_dropout,
         label="MC Dropout", color="green")

plt.plot(number_of_ensembles, brier_score_random,
         label="Ensemble + R", color="grey")

plt.plot(number_of_ensembles, brier_score_adversarial,
         label="Ensemble + AT", color="blue")

plt.xlabel("Number of Nets", fontsize=18)
plt.ylabel("Brier Score", fontsize=18)
plt.title("Brier Score of Deep Ensembles vs MC Dropout", fontsize=20)

plt.legend(fontsize=18, markerscale=1.5)
plt.xticks(fontsize=14)
plt.yticks(fontsize=12)

plt.savefig("plots/brier_score_deep_ensembles_vs_mc_dropout")
plt.clf()
